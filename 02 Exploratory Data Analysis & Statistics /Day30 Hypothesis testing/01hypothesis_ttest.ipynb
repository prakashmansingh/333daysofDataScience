# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import ttest_ind

# %% [markdown]
# Simulated sales data

# %%
sales_before = np.array([210, 220, 230, 200, 250, 240, 225, 215, 205, 230])
sales_after = np.array([280, 300, 310, 290, 305, 295, 310, 320, 300, 315])

# %% [markdown]
# Hypothesis Testing

# %%
t_stat, p_value = ttest_ind(sales_before, sales_after)
alpha = 0.05
reasult = "Significient Increase" if p_value < alpha else "No Significient Increase"

# %% [markdown]
# Visualization

# %%
plt.figure(figsize=(8,6))
data = {
    "Sales": np.concatenate([sales_before, sales_after]),
    "Period": ["Before Dashain"]*len(sales_before) + ["After Dashain"]*len(sales_after)
}
sns.boxplot(x="Period", y="Sales", data=data, palette="Set2")
sns.swarmplot(x="Period", y="Sales", data=data, color=".25")
plt.title("Sales Before and After Dashain Festival")
plt.ylabel("Sales Amount")
plt.xlabel("Period")
plt.figtext(0.5, -0.1, f"T-statistic: {t_stat:.2f}, P-value: {p_value:.4f} -> {reasult}", ha="center", fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/k9/0ymr366x2c5c2hpzhnpzt0100000gn/T/ipykernel_4161/1634058442.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Period", y="Sales", data=data, palette="Set2")
